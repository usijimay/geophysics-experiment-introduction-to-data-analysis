# %% [markdown]
# # 第13回 提出演習
#
# 授業で扱った豊後水道北部とは**別の海域**の水温データを使って、同じ解析を自分で行います。
#
# 気象庁「日本沿岸域の海面水温情報」から指定された海域のデータをダウンロードし、
# JupyterLiteにアップロードしてから始めてください。
#
# ### 提出について
# このNotebookにコード・計算結果・必要な説明を記入し、`.ipynb` ファイルをMoodleから提出してください。

# %% [markdown]
# ## 課題1：水温の長期変化を求める
#
# 授業で扱った海域とは別の海域について、以下を行ってください。
#
# 1. ダウンロードしたデータをpandasで読み込む
# 2. 年平均水温を計算する
# 3. 年平均水温の時間変化を図示する
# 4. 最小二乗法を用いて、水温の長期的な変化傾向を求める
# 5. 求めた最小二乗直線を年平均水温の図に重ねる
#
# ### ヒント
# - `pd.read_csv()` でデータを読み込めます。
# - 年平均には `groupby()` と `mean()` を使います。
# - 年と水温からそれぞれ平均値を引いてから、授業で使った最小二乗法の式を利用できます。
# - 最後に、傾きを「1年あたり」または「10年あたり」の水温変化として解釈してください。

# %%
# 課題1
# ここにコードを書いてください

# %% [markdown]
# ### 課題1：結果の説明
#
# 求めた水温の変化傾向について、結果を簡潔に説明してください。

# %% [markdown]
# **回答：**
#
# ここに記入してください。

# %% [markdown]
# ## 課題2：時間と水温の相関係数を求める
#
# 課題1で使用した年平均水温について、**年と水温の相関係数**を求めてください。
#
# ### ヒント
# 授業で扱った相関係数
#
# \[
# r=
# \frac{
# \frac{1}{N}\sum_i x_i y_i
# }{
# \sqrt{\frac{1}{N}\sum_i x_i^2}
# \sqrt{\frac{1}{N}\sum_i y_i^2}
# }
# \]
#
# を使って計算できます。
#
# `pandas` の `corr()` や NumPy の `corrcoef()` を使って確認しても構いません。

# %%
# 課題2
# ここにコードを書いてください

# %% [markdown]
# ### 課題2：結果の説明
#
# 求めた相関係数から、時間と水温の関係について簡潔に説明してください。

# %% [markdown]
# **回答：**
#
# ここに記入してください。

# %% [markdown]
# ## 課題3：2つの海域の関係を調べる
#
# 授業で使用した豊後水道北部のデータと、課題1で使用した別海域のデータを比較します。
#
# 1. 2海域の年平均水温を用意する
# 2. 2海域の水温の相関係数を求める
# 3. 一方の海域を x、もう一方の海域を y として散布図を作成する
# 4. 最小二乗法を用いて、2海域の水温変動の平均的な比を求める
#
# ### ヒント
# - 比較する2つの時系列は、同じ年のデータ同士を対応させます。
# - それぞれの年平均水温から平均値を引いて偏差を作ります。
# - 相関係数は課題2と同じ考え方で計算できます。
# - 2つの偏差を `x`, `y` と考えれば、授業で扱った最小二乗法をそのまま利用できます。
# - 散布図に最小二乗直線を重ねると、結果を確認しやすくなります。

# %%
# 課題3
# ここにコードを書いてください

# %% [markdown]
# ### 課題3：結果の説明
#
# 2海域の相関係数と、最小二乗法で求めた値がそれぞれ何を表しているか、簡潔に説明してください。

# %% [markdown]
# **回答：**
#
# ここに記入してください。
